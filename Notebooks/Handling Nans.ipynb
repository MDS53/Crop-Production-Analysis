# %%
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('Crop Production data (1).csv')

# %%
df.head()
# Out:
#                     State_Name District_Name  Crop_Year       Season  \
# 0  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
#
#                   Crop    Area  Production
# 0             Arecanut  1254.0      2000.0
# 1  Other Kharif pulses     2.0         1.0
# 2                 Rice   102.0       321.0
# 3               Banana   176.0       641.0
# 4            Cashewnut   720.0       165.0

# %%
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 246086                  West Bengal       PURULIA       2014  Summer
# 246087                  West Bengal       PURULIA       2014  Summer
# 246088                  West Bengal       PURULIA       2014  Whole Year
# 246089                  West Bengal       PURULIA       2014  Winter
# 246090                  West Bengal       PURULIA       2014  Winter
#
#                        Crop      Area  Production
# 0                  Arecanut    1254.0      2000.0
# ...

# %%
Train=df[df['Production'].notnull()]
Test=df[df['Production'].isnull()]

# %%
Train
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 246086                  West Bengal       PURULIA       2014  Summer
# 246087                  West Bengal       PURULIA       2014  Summer
# 246088                  West Bengal       PURULIA       2014  Whole Year
# 246089                  West Bengal       PURULIA       2014  Winter
# 246090                  West Bengal       PURULIA       2014  Winter
#
#                        Crop      Area  Production
# 0                  Arecanut    1254.0      2000.0
# ...

# %%
from catboost import CatBoostRegressor, Pool

# Sample data with categorical features
X = [
    ['Karnataka', 'Bangalore', 2015, 'Kharif', 'Rice', 100.0],
    ['Karnataka', 'Mysore', 2016, 'Rabi', 'Wheat', 150.0],
    ['Tamil Nadu', 'Chennai', 2017, 'Kharif', 'Rice', 200.0],
    ['Tamil Nadu', 'Madurai', 2018, 'Rabi', 'Maize', 250.0]
]
labels = [500, 600, 700, 800]

# Indicating the categorical feature indices
categorical_features_indices = [0, 1, 3, 4]

# Creating a Pool object to handle data with categorical features
train_data = Pool(data=data, label=labels, cat_features=categorical_features_indices)

# Initializing and training the CatBoost regressor
model = CatBoostRegressor(cat_features=categorical_features_indices, verbose=0)
model.fit(train_data)

# Making predictions
predictions = model.predict(data)
print(predictions)

# %%
X_train,y_train=Train.drop(['Production'],axis=1),Train[['Production']]

# %%
X_test,y_test=Test.drop(['Production'],axis=1),Test[['Production']]

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((242361, 6), (3730, 6), (242361, 1), (3730, 1))

# %%
Train=df.drop(['Production'],axis=1)
Test=df[['Production']]

# %%
Dt=DecisionTreeRegressor()

# %%
Dt.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9288\2848722435.py in ?()
# ----> 1 Dt.fit(X_train,y_train)
#
# c:\Users\new\anaconda3\envs\Abalone\lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1148                 skip_parameter_validation=(
#    1149                     prefer_skip_nested_validation or global_skip_validation
#    1150                 )
#    1151             ):
# -> 1152                 return fit_method(estimator, *args, **kwargs)
#
# c:\Users\new\anaconda3\envs\Abalone\lib\site-packages\sklearn\tree\_classes.py in ?(self, X, y, sample_weight, check_input)
#    1316         self : DecisionTreeRegressor
#    1317             Fitted estimator.
#    1318         """
#    1319
# -> 1320         super()._fit(
#    1321             X,
#    1322             y,
# ...
